# %%
import pickle

predictions_file_path = 'predictions.pickle'

with open(predictions_file_path, 'rb') as f:
    preds = pickle.load(f)

print(type(preds))
print(len(preds))
print(preds[498])
# Out:
# <class 'dict'>
# 3021
# [array([177, 382, 248, 534], dtype=int32)]
